# %%
from osgeo import gdal as gd
import gdalconst as C

# %%
f = "hdf_files/AERONET_Fort_McMurray.2016136.terra.721.250m.tif"
dataset = gd.Open(f, gd.GA_ReadOnly)

# %%
dataset
# Out:
# <osgeo.gdal.Dataset; proxy of <Swig Object of type 'GDALDatasetShadow *' at 0x7f214b4b3330> >

# %%
print(dataset.GetProjection())
# Out:
# GEOGCS["WGS 84",DATUM["WGS_1984",SPHEROID["WGS 84",6378137,298.257223563,AUTHORITY["EPSG","7030"]],AUTHORITY["EPSG","6326"]],PRIMEM["Greenwich",0],UNIT["degree",0.0174532925199433],AUTHORITY["EPSG","4326"]]

# %%
help(gd)
# Out:
# Help on module osgeo.gdal in osgeo:
#
# NAME
#     osgeo.gdal
#
# DESCRIPTION
#     # This file was automatically generated by SWIG (http://www.swig.org).
#     # Version 1.3.40
#     #
#     # Do not make changes to this file unless you know what you are doing--modify
#     # the SWIG interface file instead.
#     # This file is compatible with both classic and new-style classes.
#
# CLASSES
#     builtins.object
#         AsyncReader
#         ColorEntry
#         ColorTable
#         GCP
#         MajorObject
#             Band
#             Dataset
#             Driver
#         RasterAttributeTable
#         StatBuf
#         Transformer
#         VirtualMem
#
#     class AsyncReader(builtins.object)
#      |  Proxy of C++ GDALAsyncReaderShadow class
#      |
#      |  Methods defined here:
#      |
#      |  GetBuffer(self, *args)
#      |      GetBuffer(self)
#      |
#      |  GetNextUpdatedRegion(self, *args)
# ...

# %%
print(dataset.GetDescription())
# Out:
# hdf_files/AERONET_Fort_McMurray.2016136.terra.721.250m.tif

# %%
print(dataset.ComputeStastics())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-33-2f13282af48c> in <module>()
# ----> 1 print(dataset.ComputeStastics())
#
# /home/hadleigh/miniconda3/lib/python3.5/site-packages/osgeo/gdal.py in <lambda>(self, name)
#     637     __swig_getmethods__ = {}
#     638     for _s in [MajorObject]: __swig_getmethods__.update(getattr(_s,'__swig_getmethods__',{}))
# --> 639     __getattr__ = lambda self, name: _swig_getattr(self, Dataset, name)
#     640     def __init__(self, *args, **kwargs): raise AttributeError("No constructor defined")
#     641     __repr__ = _swig_repr
#
# /home/hadleigh/miniconda3/lib/python3.5/site-packages/osgeo/gdal.py in _swig_getattr(self, class_type, name)
#      52     method = class_type.__swig_getmethods__.get(name,None)
#      53     if method: return method(self)
# ---> 54     raise AttributeError(name)
#      55
# ...
