# %% [markdown]
# # Lesson 5: Python for GIS. (The brief introduction)

# %% [markdown]
# ## Sections:
#
# 1. [File Requirements](#step_1)
# 2. [Using Python](#step_2)
# 3. [Using a Clipped Layer](#step_3)
#
#
# - [pyShp Help](#sf.help)
# - [Suggested Readings](#readings)
# - [References](#references)

# %% [markdown]
# # <a id='step_1'></a>

# %% [markdown]
# ## Step 1: File Requirements
#
# As you may have caught on from the previous readings and references, the 'shapefiles' that are used for the background and basemaps on our map canvas (ie. our vector layers) ar not just a single file at all. Each shapefiles requires the collection of three files:
#
# 1. A **.shp** file which acts as the main file
#
# 2. A **.shx** file which contains indexing data
#
# 3. A **.dbf** file which is the database file, containing the geomtery attributes
#
#
# - See *"Learning Geospatial analysis with Python 2nd Ed"* page 62 for more on file types.
#
# For the examples in this lesson we will be using files that have been retrieved as **.zip** packages, and unzipped or extraced into a directory with the same name as the files it contains.
#
# **Important:** if you wish to change a file name, you either do it to all the files in that folder, or use an app such as **QGIS Browser** to ensure you don't end up with an orphaned .shp file. That is, when you open a .shp file in QGIS, it is expecting there to be *at least* the .shx and .dbf files with the same name/prefix in the same directory.
#
# From here-on-in: the term **shapefile** will refer the generic collection of files required, not any particular extension.

# %% [markdown]
# # <a id='step_2'></a>

# %% [markdown]
# ## Step 2: Using Python
#
# Although QGIS does come bundled with python 2.7, and has a interactive window within the QGIS GUI, we will be sticking with scripting some tools to use upon shapefiles independently of QGIS. This is for a couple of reasons:
#
# - At the time of writing, QGIS 3.x is on its way, but with an undertermined time frame. QGIS 3.0 will be using Python 3.x. see <a href='http://blog.qgis.org/2016/02/10/qgis-3-0-plans/'>QGIS 3 Blog.</a>. Switching between python 2 and python 3 is best left to those that have no other choice.
#
#
# - Using the pyShp library we can treat shapefiles like any other database file, and access most of its information in the form of lists. This is good practise for programming in general, and lets us explore the way shapefiles are generically written for all GIS application.
#
#
# - When we read and write files in pyShp we will be creating object instances, and is a *fairly* painless way to get acquainted with object orientated programming.
#
#
# - This is just an introduction, so we better leave something for you to do on your summer holidays.

# %% [markdown]
# First thing we will need is the pyShp library. On the command line/terminal:

# %% [markdown]
# ```
# pip install physhp
# ```

# %% [markdown]
# - This library is wriiten by Joel Lawhead, and has pretty good documentation at https://pypi.python.org/pypi/pyshp.
#
# As with any script that is reading / writing files, the complier needs to know where these files are kept. For the instructions below, make sure you either replace the given path with the approprite directory/folder etc for the script to find the shapefiles, or ```cd``` to the directory in the terminal and run python directly from there.
#
# Firstly, we will start by taking a shapefile form Stats Canada that shows the boundaries of all provinces and territoires. We will create a new file with a only a selcted province 'clipped' from the original file:

# %%
# importing the pyShp library

import shapefile as sf

# %%
# create a reader instance

in_file = sf.Reader("Data/stats_canada/gpr_000b11a_e")

# %% [markdown]
# Each shapefile has a 'shapeType' indicating if it is holding point data, polygon data, etc:

# %%
in_file.shapeType
# Out:
# 5

# %% [markdown]
# Since we are going to clip a section of this vector layer to create another file, we want make sure the file types are the same, and create an instance of a writer object by:

# %%
# create a writer instance

out_file = sf.Writer(in_file.shapeType)

# %% [markdown]
# The file then has 'feilds' to explore, yet in this case they are very brief. The 'deletion flag' is to do with the .dbf database, and is a hidden feild. In the "Canada" file the only other two fields are the names of the provinces and terrritories. One field for English, the other for French:

# %%
in_file.fields
# Out:
# [('DeletionFlag', 'C', 1, 0),
#  ['PRUID', 'C', 2, 0],
#  ['PRNAME', 'C', 55, 0],
#  ['PRENAME', 'C', 30, 0],
#  ['PRFNAME', 'C', 30, 0],
#  ['PREABBR', 'C', 10, 0],
#  ['PRFABBR', 'C', 10, 0]]

# %% [markdown]
# We will want our writer instance to write the same fields too:

# %%
out_file.fields = list(in_file.fields)

# %% [markdown]
# The names of the proviences / territories are in the files 'records':

# %%
in_file.records()
# Out:
# [['59',
#   'British Columbia / Colombie-Britannique',
#   'British Columbia',
#   'Colombie-Britannique',
#   'B.C.',
#   'C.-B.'],
#  ['24', b'Quebec / Qu\xe9bec', 'Quebec', b'Qu\xe9bec', 'Que.', 'Qc'],
#  ['62', 'Nunavut', 'Nunavut', 'Nunavut', 'Nvt.', 'Nt'],
#  ['11',
#   b'Prince Edward Island / \xcele-du-Prince-\xc9douard',
#   'Prince Edward Island',
#   b'\xcele-du-Prince-\xc9douard',
#   'P.E.I.',
#   b'\xce.-P.-\xc9.'],
#  ['47', 'Saskatchewan', 'Saskatchewan', 'Saskatchewan', 'Sask.', 'Sask.'],
#  ['60', 'Yukon', 'Yukon', 'Yukon', 'Y.T.', 'Yn'],
#  ['46', 'Manitoba', 'Manitoba', 'Manitoba', 'Man.', 'Man.'],
#  ['35', 'Ontario', 'Ontario', 'Ontario', 'Ont.', 'Ont.'],
#  ['13',
#   'New Brunswick / Nouveau-Brunswick',
#   'New Brunswick',
#   'Nouveau-Brunswick',
#   'N.B.',
#   'N.-B.'],
#  ['61',
#   'Northwest Territories / Territoires du Nord-Ouest',
#   'Northwest Territories',
#   'Territoires du Nord-Ouest',
#   'N.W.T.',
#   'T.N.-O.'],
#  ['48', 'Alberta', 'Alberta', 'Alberta', 'Alta.', 'Alb.'],
#  ['10',
#   'Newfoundland and Labrador / Terre-Neuve-et-Labrador',
#   'Newfoundland and Labrador',
#   'Terre-Neuve-et-Labrador',
#   'N.L.',
#   'T.-N.-L.'],
#  ['12',
#   b'Nova Scotia / Nouvelle-\xc9cosse',
#   'Nova Scotia',
#   b'Nouvelle-\xc9cosse',
#   'N.S.',
#   b'N.-\xc9.']]

# %% [markdown]
# From here we can identify the index for a particular province, say **Alberta**.
#
# (note the difference in the syntax between **.records()** and **.record(i)**)

# %%
in_file.record(10)
# Out:
# ['48', 'Alberta', 'Alberta', 'Alberta', 'Alta.', 'Alb.']

# %% [markdown]
# One of the properties of the object instance is the 'bounding box', which the smallest square/rectangle that can be drawn around the object in question. That is, it gives the lower left corner points, and the upper right corner points of the box surrounding in this case the whole of Canada. If we think about these as X and Y, the reading of the points goes:
# - bbox: [Xmin, Ymin, Xmax, Ymax.]

# %%
in_file.bbox
# Out:
# [-141.01807315799994, 41.681435425000075, -52.61940850399992, 83.13550252400006]

# %% [markdown]
# When QGIS reads these points together with a metadata file, it then knows where Canada fits on the map canvas. These points are important because you may want to see if features from another file are contained inside this bounding box.
#
# The outlines / polygons of the provinces are known as .shapes, and in this case there is one 'shape' for each province territory:

# %%
len(in_file.shapes())
# Out:
# 13

# %% [markdown]
# Again, we can just select the shape we want, and we will access the data for Alberta with it being the 11th entry:

# %%
alberta = in_file.shape(10)
alberta

# %% [markdown]
# We can look at the attributes of this shape now, withour getting all the data for all other proviences:

# %%
for name in dir(alberta): 
    print(name)
# Out:
# __class__
# __delattr__
# __dict__
# __dir__
# __doc__
# __eq__
# __format__
# __ge__
# __geo_interface__
# __getattribute__
# __gt__
# __hash__
# __init__
# __le__
# __lt__
# __module__
# __ne__
# __new__
# __reduce__
# __reduce_ex__
# __repr__
# __setattr__
# __sizeof__
# __str__
# __subclasshook__
# __weakref__
# bbox
# parts
# points
# shapeType

# %%
print(alberta.shapeType)
print(alberta.bbox)
# Out:
# 5
# [-120.00029747299993, 48.99999999400006, -109.9998580489999, 60.00007326000008]

# %% [markdown]
# We can see that the bounding box for alberta is smaller (contained within) the larger bounding box for the Canada file.
#
# The main thing we are looking for are the **points**, which dictate the shape of Alberta. Each province has a different number of points, depending on the shape and complexity of the outline of the province. Once again though, these points seem fairly abstract to us, as we cannot just read them as latitude and longitude coords.

# %%
print("Numbers of point-pairs in Alberta boarder: {}" .format(len(alberta.points)))

# Uncomment the line below to see the list of point-pairs:
# alberta.points
# Out:
# Numbers of point-pairs in Alberta boarder: 17996

# %% [markdown]
# So, now all we need to 'clip' Alberta from the Canada shapefile is to write the 'shape' of Aberta to the out_file, and write the corresponding record. PyShp will write all three file type we mentioned early when you save to a common directory:

# %%
out_file.records.append(in_file.record(10))
out_file._shapes.append(alberta)
out_file.save("Data/Alberta/Alberta")

# %% [markdown]
# # <a id='step_3'></a>

# %% [markdown]
# ## Step 3: Using a Clipped Layer:
#
# Now its simply a case of adding the layer to the QGIS map canvas.
#
# You may get asked to verify the desired projection upon importing, in this case if we look at the original **Canada.shpX.xml** file we see that it should be a North America 83 projection. If we filter the CGS options for **Canada** we even get a **NAD 83 / Satistics Canada Lambert** option, so lets use that. (Remeber, you may wish to investigate what a given projection is designed for before trusting it for certain measuments).
#
# The screenshot below shows the clipped ploygon of Alberta overlying the original layer of Canada:

# %%
from IPython.display import Image
Image(filename='Images/lesson5_1.png', width=800, height=800)

# %% [markdown]
# # <a id='sf.help'></a>

# %% [markdown]
# ## pyShp Help

# %%
# Uncomment the lines below and run the cell to read the documentaion regarding classes / methods / inheritence etc:

# import shapefile as sf
# help(sf)

# %% [markdown]
# # <a id='readings'></a>

# %% [markdown]
# ## Suggested Readings
#
# - Familiarize with the *"Boundary Files, Reference Guide"*. Statistics Canada. 2011. (Found in /Data/stats_canada/ directory.)

# %% [markdown]
# # <a id='references'></a>

# %% [markdown]
# ## References
#
# - Python pyShp library: https://pypi.python.org/pypi/pyshp. Python Software Foundation. 2015.
#
# - Lawhead, J; *"Learning Geospatial Analysis with Python Second Edition"*. Packt Publishing. 2015
#
# - *"ESRI Shapefile Technical Discription"*. Environmental Systems Research Institute, Inc. 1998.
#
# - Lawhead, J; <a href='http://geospatialpython.com/2015/05/clipping-shapefile-in-pure-python.html'>*"Clipping a Shapefile in Pure Python"*</a> . GeospatialPython. 2015
